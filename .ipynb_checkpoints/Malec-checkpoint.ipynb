# %%
library(dplyr)
library(ggplot2)
library(zeallot)

# %%
analysis <- function(X, Y, display_plot=TRUE){
    spearman <- cor(X, Y, use="pairwise.complete.obs", method="spearman")
    pearson <- cor(X, Y, use="pairwise.complete.obs", method="pearson")
    print(c("Pearson", pearson))
    print(c("Spearman", spearman))
    if (display_plot) {
        ggplot() + geom_point(aes(x=X, y=Y))
    }
}

regression <- function(X, Y, display_plot=TRUE){
    r <- cor(X, Y, use="pairwise.complete.obs")
    Sx <- sd(X)
    Sy <- sd(Y)
    a <- r * Sy / Sx
    b <- mean(Y) - a * mean(X)

    if(display_plot){
        xs <- seq(min(X), max(X), 0.01)
        plt <- ggplot() +
            geom_point(aes(x=X, y=Y), alpha=0.5) +
            geom_line(aes(x = xs, y = a * xs + b), linewidth=1, col="red")
        show(plt)
    }

    return(c(a, b))
}

# %%
data <- read.csv("data.csv")
data2000 <- data %>% filter(year == 2000)
data2005 <- data %>% filter(year == 2005)
data2010 <- data %>% filter(year == 2010)
data2015 <- data %>% filter(year == 2015)
poland <- data %>% filter(country == "Poland")

# %%
data[4:22] %>%
  gather(-life_expectancy, key = "var", value = "value") %>% 
  ggplot(aes(x = value, y = life_expectancy)) +
    geom_point(size=0.4, alpha=0.4, col='#0575d0', stroke=0) +
    facet_wrap(~ var, scales='free', nrow=6)
# Out:
# Error in gather(., -life_expectancy, key = "var", value = "value"): nie udało się znaleźć funkcji 'gather'
# Traceback:
#
# 1. data[4:22] %>% gather(-life_expectancy, key = "var", value = "value") %>%
#  .     ggplot(aes(x = value, y = life_expectancy))
# 2. ggplot(., aes(x = value, y = life_expectancy))

# %%
le <- c()
years <- sort(unique(data$year))

for (y in years) {
    data_year <- data %>% filter(year == y & !is.na(life_expectancy) & !is.na(population))
    mean_lf <- sum(data_year$life_expectancy * data_year$population) / sum(data_year$population)
    le <- append(le, mean_lf)
}

ggplot() + geom_line(aes(x=years, y=le))
# Out:
# plot without title

# %%
regression(years, le)
# Out:
# [1]    0.3644112 -663.9382578
# plot without title

# %%
analysis(data$alcohol, data$life_expectancy)
# Out:
# [1] "Pearson"           "0.404876761126602"
# [1] "Spearman"          "0.442504524305733"
# Warning message:
# "Removed 203 rows containing missing values (`geom_point()`)."
# plot without title

# %%
analysis(data$HIV_AIDS, data$life_expectancy)
# Out:
# [1] "Pearson"            "-0.556556253400693"
# [1] "Spearman"           "-0.753641880116125"
# Warning message:
# "Removed 10 rows containing missing values (`geom_point()`)."
# plot without title

# %%
analysis(data$GDP, data$life_expectancy)
# Out:
# [1] "Pearson"           "0.461455192620738"
# [1] "Spearman"          "0.642470938054315"
# Warning message:
# "Removed 453 rows containing missing values (`geom_point()`)."
# plot without title

# %%
analysis(data$adult_mortality, data$life_expectancy)
# Out:
# [1] "Pearson"            "-0.696359313769976"
# [1] "Spearman"           "-0.650006967892821"
# Warning message:
# "Removed 10 rows containing missing values (`geom_point()`)."
# plot without title

# %%
xs <- seq(0, 750, 1)
a <- -0.5
b <- 100
ys <- a * xs + b
ggplot() +
    geom_point(aes(data$adult_mortality, data$life_expectancy)) +
    geom_point(aes(poland$adult_mortality, poland$life_expectancy, col='red')) +
    geom_line(aes(xs, ys)) +
    ylim(30, 90) +
    theme(legend.position='none')
# Out:
# Warning message:
# "Removed 10 rows containing missing values (`geom_point()`)."
# Warning message:
# "Removed 630 rows containing missing values (`geom_line()`)."
# plot without title

# %%
data$type <- 0
data$type[data$life_expectancy < a * data$adult_mortality + b] <- 1
ggplot(data, aes(x=adult_mortality, y=life_expectancy, col=data$type)) + geom_point()
# Out:
# Warning message:
# "Use of `data$type` is discouraged.
# i Use `type` instead."
# Warning message:
# "Removed 10 rows containing missing values (`geom_point()`)."
# plot without title

# %%
filtered_data <- data %>% filter(type == 0)
ggplot() + geom_histogram(aes(filtered_data$adult_mortality), bins=15)
# Out:
# Warning message:
# "Removed 10 rows containing non-finite values (`stat_bin()`)."
# plot without title

# %%
data %>% filter(type == 1)
# Out:
#     country                                              year status
# 1   Afghanistan                                          2002 Developing
# 2   Albania                                              2014 Developing
# 3   Albania                                              2008 Developing
# 4   Albania                                              2007 Developing
# 5   Albania                                              2005 Developing
# 6   Albania                                              2004 Developing
# 7   Albania                                              2003 Developing
# 8   Albania                                              2002 Developing
# 9   Albania                                              2001 Developing
# 10  Albania                                              2000 Developing
# 11  Algeria                                              2015 Developing
# 12  Algeria                                              2014 Developing
# 13  Algeria                                              2004 Developing
# 14  Angola                                               2001 Developing
# 15  Angola                                               2000 Developing
# 16  Antigua and Barbuda                                  2015 Developing
# 17  Antigua and Barbuda                                  2009 Developing
# 18  Argentina                                            2012 Developing
# 19  Argentina                                            2011 Developing
# 20  Argentina                                            2004 Developing
# 21  Armenia                                              2014 Developing
# 22  Armenia                                              2008 Developing
# 23  Australia                                            2014 Developed
# 24  Austria                                              2012 Developed
# 25  Austria                                              2007 Developed
# 26  Austria                                              2002 Developed
# 27  Azerbaijan                                           2010 Developing
# 28  Azerbaijan                                           2007 Developing
# 29  Azerbaijan                                           2000 Developing
# 30  Bahamas                                              2014 Developing
# ... ...                                                  ...  ...
# 492 United Arab Emirates                                 2002 Developing
# 493 United Arab Emirates                                 2001 Developing
# 494 United Arab Emirates                                 2000 Developing
# 495 United Kingdom of Great Britain and Northern Ireland 2008 Developed
# 496 United Kingdom of Great Britain and Northern Ireland 2007 Developed
# 497 United Republic of Tanzania                          2014 Developing
# 498 United Republic of Tanzania                          2010 Developing
# 499 United Republic of Tanzania                          2002 Developing
# 500 United Republic of Tanzania                          2001 Developing
# 501 United States of America                             2015 Developed
# 502 United States of America                             2014 Developed
# 503 United States of America                             2013 Developed
# 504 United States of America                             2012 Developed
# 505 United States of America                             2011 Developed
# 506 United States of America                             2010 Developed
# 507 United States of America                             2009 Developed
# 508 United States of America                             2008 Developed
# 509 United States of America                             2007 Developed
# 510 Vanuatu                                              2015 Developing
# 511 Vanuatu                                              2000 Developing
# 512 Viet Nam                                             2012 Developing
# 513 Yemen                                                2007 Developing
# 514 Yemen                                                2002 Developing
# 515 Zambia                                               2015 Developing
# 516 Zambia                                               2008 Developing
# 517 Zambia                                               2003 Developing
# 518 Zambia                                               2002 Developing
# 519 Zimbabwe                                             2007 Developing
# 520 Zimbabwe                                             2006 Developing
# 521 Zimbabwe                                             2002 Developing
#     life_expectancy adult_mortality infant_deaths alcohol
# 1   56.2             3              88             0.01
# 2   77.5             8               0             4.51
# 3   75.3             1               1             5.61
# 4   75.9             9               1             5.58
# 5   73.5            15               1             5.16
# 6   73.0            17               1             4.54
# 7   72.8            18               1             4.29
# 8   73.3            15               1             3.73
# 9   73.6            14               1             4.25
# 10  72.6            11               1             3.66
# 11  75.6            19              21               NA
# 12  75.4            11              21             0.01
# 13  72.3            14              19             0.45
# 14  45.7            44              97             2.58
# 15  45.3            48              97             1.85
# 16  76.4            13               0               NA
# 17  75.4            14               0             7.82
# 18  75.9            12               9             8.35
# 19  75.7            12               9             8.11
# 20  74.7            13              11             7.63
# 21  74.6            12               1             3.91
# 22  73.2            14               1             3.96
# 23  82.7             6               1             9.71
# 24  88.0             7               0            12.26
# 25  81.0             8               0            12.50
# 26  78.7             9               0            12.50
# 27  71.1            13               5             1.98
# 28  73.0            14               6             1.02
# 29  66.6            16               9             0.65
# 30  75.4            16               0             9.45
# ... ...             ...             ...           ...
# 492 74.7            11                1            1.72
# 493 74.5            14                1            1.67
# 494 74.2            17                1            1.64
# 495 79.6             8                4           11.47
# 496 79.5             8                4           11.84
# 497 67.0            34               86            0.01
# 498 57.5            36               89            4.19
# 499 52.0            46              106            3.37
# 500 49.6            46              110            4.09
# 501 79.3            13               23              NA
# 502 79.1            14               23            8.82
# 503 78.9            16               23            8.82
# 504 78.8            16               24            8.82
# 505 78.7            16               25            8.67
# 506 78.7            15               25            8.55
# 507 78.5            18               26            8.71
# 508 78.2            18               27            8.74
# 509 78.1            11               27            8.74
# 510 72.0            13                0              NA
# 511 69.0            18                0            1.21
# 512 75.6            13               29            4.12
# 513 63.4            24               38            0.05
# 514 61.5            25               45            0.07
# 515 61.8            33               27              NA
# 516 55.7            45               31            2.12
# 517 46.4            64               39            2.33
# 518 45.5            69               41            2.44
# 519 46.6            67               29            3.88
# 520 45.4             7               28            4.57
# 521 44.8            73               25            4.43
#     percentage_expenditure hepatitis_B measles ... total_expenditure diphtheria
# 1      16.887351           64          2486    ...  7.76             36
# 2     428.749067           98             0    ...  5.88             98
# 3      36.622068           99             0    ...  5.87             99
# 4      32.246552           98            22    ...  6.10             98
# 5      26.993121           98             6    ...  6.12             98
# 6     221.842800           99             7    ...  6.38             97
# 7      14.719289           97             8    ...  6.27             97
# 8     104.516916           96            16    ...  6.30             98
# 9      96.205571           96            18    ...  6.00             97
# 10     91.711541           96           662    ...  6.26             97
# 11      0.000000           95            63    ...    NA             95
# 12     54.237318           95             0    ...  7.21             95
# 13    220.393699           81          3289    ...  3.54             86
# 14     30.359936           NA          9046    ...  5.38             38
# 15     15.881493           NA          2219    ...  2.79             28
# 16      0.000000           99             0    ...    NA             99
# 17    149.358735           98             0    ...  4.86             99
# 18   1133.558003           91             2    ...  5.20             91
# 19   1504.329462           91             3    ...  5.89             91
# 22  0.1         41.26997    29822    2.0                2.1
# 23  0.1      62214.69120  2346694    0.6                0.6
# 24  0.1      48333.57273  8429991    1.8                2.0
# 25  0.1      46586.65250  8295487    1.7                1.9
# 26  0.1      26351.37568   881957    1.7                1.9
# 27  0.1       5842.85784   954332    2.8                2.9
# 28  0.1       3851.43787    85813    2.8                2.9
# 29  0.1        655.97433     8486    3.2                3.1
# 30  0.1               NA       NA    2.5                2.5
# ... ...      ...         ...        ...                 ...
# 492  0.1     31311.35936       NA    5.3                 5.0
# 493  0.1      3161.52935       NA    5.3                 5.1
# 494  0.1      3371.26869       NA    5.4                 5.1
# 495  0.1              NA       NA    0.8                 0.5
# 496  0.1              NA       NA    0.7                 0.5
# 497  1.4              NA       NA    6.8                 6.6
# 498  4.6              NA       NA    7.1                 7.1
# 499 12.1              NA       NA    8.0                 8.0
# 500 12.5              NA       NA    8.2                 8.1
# 501  0.1              NA       NA    0.8                 0.6
# 502  0.1              NA       NA    0.8                 0.6
# 503  0.1              NA       NA    0.7                 0.6
# 504  0.1              NA       NA    0.7                 0.6
# 505  0.1              NA       NA    0.7                 0.6
# 506  0.1              NA       NA    0.7                 0.6
# 507  0.1              NA       NA    0.7                 0.6
# 508  0.1              NA       NA    0.7                 0.6
# 509  0.1              NA       NA    0.7                 0.6
# 510  0.1       285.83414    26463    1.5                 1.4
# 511  0.1      1469.84915    18563    1.7                 1.7
# 512  0.1              NA       NA   14.4                15.0
# 513  0.1              NA       NA   13.8                13.8
# 514  0.1              NA       NA   14.0                14.0
# 515  4.1      1313.88965   161587    6.3                 6.1
# 516 11.9      1369.68249  1382517    6.8                 6.7
# 517 18.2       429.15834 11421984    7.3                 7.2
# 518 18.4       377.13524   111249    7.4                 7.3
# 519 23.7       396.99822  1332999    8.2                 8.2
# 520 26.8       414.79623 13124267    8.6                 8.6
# 521 39.8        57.34834   125525    1.2                 1.3
#     income_composition_of_resources schooling type
# 1   0.341                            6.2      1
# 2   0.761                           14.2      1
# 3   0.713                           12.0      1
# 4   0.703                           11.6      1
# 5   0.685                           10.8      1
# 6   0.681                           10.9      1
# 7   0.674                           10.7      1
# 8   0.670                           10.7      1
# 9   0.662                           10.6      1
# 10  0.656                           10.7      1
# 11  0.743                           14.4      1
# 12  0.741                           14.4      1
# 13  0.673                           11.7      1
# 14  0.391                            5.1      1
# 15  0.382                            4.6      1
# 16  0.784                           13.9      1
# 17  0.788                           14.2      1
# 18  0.822                           17.2      1
# 19  0.816                           17.1      1
# 20  0.775                           16.3      1
# 21  0.739                           12.7      1
# 22  0.721                           12.3      1
# 23  0.936                           20.4      1
# 24  0.884                           15.7      1
# 25  0.860                           15.2      1
# 26  0.847                           16.1      1
# 27  0.737                           11.7      1
# 28  0.708                           11.6      1
# 29  0.636                           10.1      1
# 30  0.789                           12.6      1
# ... ...                             ...       ...
# 492 0.803                           12.1      1
# 493 0.798                           12.0      1
# 494 0.791                           11.8      1
# 495    NA                             NA      1
# 496    NA                             NA      1
# 497    NA                             NA      1
# 498    NA                             NA      1
# 499    NA                             NA      1
# 500    NA                             NA      1
# 501    NA                             NA      1
# 502    NA                             NA      1
# 503    NA                             NA      1
# 504    NA                             NA      1
# 505    NA                             NA      1
# 506    NA                             NA      1
# 507    NA                             NA      1
# 508    NA                             NA      1
# 509    NA                             NA      1
# 510 0.598                           10.8      1
# 511 0.000                            9.6      1
# 512 0.662                           12.2      1
# 513 0.477                            8.6      1
# 514 0.450                            8.0      1
# 515 0.576                           12.5      1
# 516 0.504                           11.4      1
# 517 0.443                           10.2      1
# 518 0.433                           10.0      1
# 519 0.414                            9.6      1
# 520 0.408                            9.5      1
# 521 0.427                           10.0      1

# %%
analysis(data$GDP, data$BMI)
# Out:
# [1] "Pearson"           "0.301557394491553"
# [1] "Spearman"          "0.481300846443494"
# Warning message:
# "Removed 472 rows containing missing values (`geom_point()`)."
# plot without title

# %%
analysis(data$schooling, data$life_expectancy)
# Out:
# [1] "Pearson"           "0.751975462736698"
# [1] "Spearman"          "0.813541004769093"
# Warning message:
# "Removed 170 rows containing missing values (`geom_point()`)."
# plot without title

# %%
analysis(data$schooling, data$GDP)
# Out:
# [1] "Pearson"           "0.448272829450722"
# [1] "Spearman"          "0.665285017917609"
# Warning message:
# "Removed 451 rows containing missing values (`geom_point()`)."
# plot without title

# %%
ggplot(data[data$year == 2005,], aes(life_expectancy, weight=population)) + geom_histogram(bins=30)
# Out:
# plot without title

# %%
analysis(data2015$income_composition_of_resources, data2015$life_expectancy)
# Out:
# [1] "Pearson"           "0.907363860239579"
# [1] "Spearman"          "0.905150749344808"
# Warning message:
# "Removed 10 rows containing missing values (`geom_point()`)."
# plot without title

# %%
analysis(data2015$schooling, data2015$life_expectancy)
# Out:
# [1] "Pearson"           "0.818159436788872"
# [1] "Spearman"          "0.844347924774132"
# Warning message:
# "Removed 10 rows containing missing values (`geom_point()`)."
# plot without title

# %%
analysis(data2015$HIV_AIDS, data2015$life_expectancy)
# Out:
# [1] "Pearson"            "-0.608344937357291"
# [1] "Spearman"           "-0.777014609759447"
# plot without title

# %%
analysis(data2015$GDP, data2015$life_expectancy)
# Out:
# [1] "Pearson"           "0.454491013399891"
# [1] "Spearman"          "0.567500961689245"
# Warning message:
# "Removed 29 rows containing missing values (`geom_point()`)."
# plot without title

# %%
correlations <- data.frame()
years <- sort(unique(data$year))
for (y in years) {
    data_year <- data %>% filter(year == y)
    rs <- c()
    for (column in colnames(data_year[5:22])) {
        r <- cor(data_year$life_expectancy, data_year[column], use="pairwise.complete.obs", method="kendall")
        rs <- append(rs, r)
    }
    correlations <- rbind(correlations, rs)
}
correlations <- cbind(years, correlations)
names(correlations) <- colnames(data[c(2, 5:22)])
correlations
# Out:
#    year adult_mortality infant_deaths alcohol    percentage_expenditure
# 1  2000 -0.4957653      -0.4130803    0.28272807 0.371209971
# 2  2001 -0.5024740      -0.4335143    0.26875701 0.359534523
# 3  2002 -0.5048538      -0.4400805    0.28894384 0.388869733
# 4  2003 -0.4864669      -0.4377216    0.28617546 0.391725475
# 5  2004 -0.6338772      -0.4367853    0.29062443 0.363209068
# 14  0.2598957        0.3918882  -0.6233407 0.4250398 -0.0839925953
# 15  0.2704304        0.3632035  -0.6188354 0.4162408 -0.0940990217
# 16 -1.0000000        0.3746902  -0.6286799 0.4056647 -0.0008008427
#    thinness_1_19_years thinness_5_9_years income_composition_of_resources
# 1  -0.3851752          -0.3820287         0.5636755
# 2  -0.3503580          -0.3509475         0.6075839
# 3  -0.4169309          -0.3913229         0.6047972
# 4  -0.3956001          -0.4057886         0.6257447
# 5  -0.4164567          -0.4323920         0.6373517
# 6  -0.4304668          -0.4824761         0.6469695
# 7  -0.4696520          -0.5038925         0.7177829
# 8  -0.4856267          -0.4811240         0.7101574
# 9  -0.4906133          -0.4820963         0.6978062
# 10 -0.4792548          -0.4760686         0.6869674
# 11 -0.4407712          -0.4441718         0.7092733
# 12 -0.4373223          -0.4334367         0.7216572
# 13 -0.4089077          -0.4347290         0.7180234
# 14 -0.4447554          -0.4530854         0.7132846
# 15 -0.4445297          -0.4702879         0.7144741
# 16 -0.4647443          -0.4770498         0.7288175
#    schooling
# 1  0.5805814
# 2  0.5726098
# 3  0.5657628
# 4  0.5763065
# 5  0.5842530
# 6  0.5863253
# 7  0.6266369
# 8  0.6055900
# 9  0.5908941
# 10 0.5774455
# 11 0.6129351
# 12 0.6160838
# 13 0.6240164
# 14 0.6277612
# 15 0.6401534
# 16 0.6433017

# %% [markdown]
# # Polska

# %%
poland
# Out:
#    country year status    life_expectancy adult_mortality infant_deaths alcohol
# 1  Poland  2015 Developed 77.5            117             2                NA
# 2  Poland  2014 Developed 77.3             12             2             10.71
# 3  Poland  2013 Developed 77.1             12             2             11.63
# 4  Poland  2012 Developed 76.8            125             2             10.81
# 5  Poland  2011 Developed 76.7            128             2             10.93
# 6  Poland  2010 Developed 76.3             13             2             10.59
# 7  Poland  2009 Developed 75.7            136             2             10.70
# 8  Poland  2008 Developed 75.5             14             2             11.40
# 9  Poland  2007 Developed 75.3            144             2             10.90
# 10 Poland  2006 Developed 75.2            144             2             10.40
# 11 Poland  2005 Developed 75.0            144             2              9.50
# 12 Poland  2004 Developed 74.9            143             2              9.19
# 13 Poland  2003 Developed 74.7            142             3              9.06
# 14 Poland  2002 Developed 74.5            145             3              8.02
# 15 Poland  2001 Developed 74.2            149             3              7.74
# 16 Poland  2000 Developed 73.7            153             3              8.40
#    percentage_expenditure hepatitis_B measles ... polio total_expenditure
# 1     0.000000            96            0     ... 92      NA
# 2   243.808475            96            0     ... 94    6.35
# 3    23.435335            96           84     ... 95    6.40
# 4   230.040097            97           71     ... 95    6.62
# 5   250.077378            98            0     ... 96    6.70
# 6   220.491685            98           13     ... 96    6.88
# 7  1299.159757            98          115     ... 96    7.12
# 8    15.714748            98            0     ... 96    6.88
# 9    14.304245            98           40     ... 99    6.28
# 10    9.145556            98          120     ... 99    6.17
# 11   79.415027            98           13     ... 99    6.20
# 12  648.074345            98           11     ... 99    6.19
# 13  542.023500            97           48     ... 98    6.22
# 14  516.055439            98           34     ... 98    6.32
# 15  466.738311            95          133     ... 98    5.86
# 16  412.432397            99           77     ... 98    5.50
#    diphtheria HIV_AIDS GDP        population thinness_1_19_years
# 1  98         0.1      12565.9876 37986412   1.9
# 2  98         0.1      14341.6750  3811735   1.9
# 3  99         0.1       1378.5491   384196   2.0
# 4  99         0.1      13145.1484  3863164   2.0
# 5  99         0.1      13893.1877  3863255   2.0
# 6  99         0.1      12599.5249  3842794   2.1
# 7  99         0.1      11527.5932  3815163   2.1
# 8  99         0.1        141.4469 38125759   2.2
# 9  99         0.1       1126.3185   381256   2.2
# 10 99         0.1         94.7726 38141267   2.3
# 11 99         0.1        821.2516 38165445   2.3
# 12 99         0.1       6681.1788 38182222   2.4
# 13 99         0.1       5693.5242   382457   2.4
# 14 99         0.1       5196.9329  3823364   2.5
# 15 98         0.1       4981.1986  3824876   2.5
# 16 98         0.1       4492.7276 38258629   2.5
#    thinness_5_9_years income_composition_of_resources schooling
# 1  2.0                0.852                           16.4
# 2  2.1                0.850                           16.4
# 3  2.1                0.838                           15.4
# 4  2.1                0.834                           15.3
# 5  2.2                0.829                           15.4
# 6  2.2                0.822                           15.1
# 7  2.3                0.818                           15.1
# 8  2.3                0.813                           15.0
# 9  2.4                0.808                           15.0
# 10 2.4                0.803                           15.0
# 11 2.5                0.797                           14.8
# 12 2.5                0.800                           15.5
# 13 2.6                0.796                           15.3
# 14 2.6                0.790                           15.0
# 15 2.7                0.784                           14.7
# 16 2.8                0.777                           14.6

# %%
analysis(poland$income_composition_of_resources, poland$life_expectancy)
# Out:
# [1] "Pearson"           "0.991807943340656"
# [1] "Spearman"          "0.997058823529412"
# plot without title

# %%
ggplot(poland, aes(x=year, y=life_expectancy)) + geom_line(show.legend = FALSE)
# Out:
# plot without title

# %%
ggplot(poland, aes(x=year, y=adult_mortality)) + geom_line(show.legend = FALSE)
# Out:
# plot without title

# %% [markdown]
# # Scattery

# %%
plt <- ggplot() + geom_point(aes(data[,"adult_mortality"]))
plt
# Out:
# ERROR while rich displaying an object: Error in `geom_point()`:
# ! Problem while setting up geom.
# i Error occurred in the 1st layer.
# Caused by error in `compute_geom_1()`:
# ! `geom_point()` requires the following missing aesthetics: y
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. doTryCatch(return(expr), name, parentenv, handler)
# 5. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 6. repr::mime2repr[[mime]](obj)
# 7. repr_text.default(obj)
# 8. paste(capture.output(print(obj)), collapse = "\n")
# 9. capture.output(print(obj))
# 10. withVisible(...elt(i))
# 11. print(obj)
# 12. print.ggplot(obj)
# 13. ggplot_build(x)
# 14. ggplot_build.ggplot(x)
# 15. by_layer(function(l, d) l$compute_geom_1(d), layers, data, "setting up geom")
# 16. try_fetch(for (i in seq_along(data)) {
#   .     out[[i]] <- f(l = layers[[i]], d = data[[i]])
#   . }, error = function(cnd) {
#   .     cli::cli_abort(c("Problem while {step}.", i = "Error occurred in the {ordinal(i)} layer."),
#   .         call = layers[[i]]$constructor, parent = cnd)
#   . })
# 17. tryCatch(withCallingHandlers(expr, error = function(cnd) {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .     }
#   .     out <- handlers[[1L]](cnd)
#   .     if (!inherits(out, "rlang_zap"))
#   .         throw(out)
#   . }), stackOverflowError = handlers[[1L]])
# 18. tryCatchList(expr, classes, parentenv, handlers)
# 19. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 20. doTryCatch(return(expr), name, parentenv, handler)
# 21. withCallingHandlers(expr, error = function(cnd) {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .     }
#   .     out <- handlers[[1L]](cnd)
#   .     if (!inherits(out, "rlang_zap"))
#   .         throw(out)
#   . })
# 22. f(l = layers[[i]], d = data[[i]])
# 23. l$compute_geom_1(d)
# 24. compute_geom_1(..., self = self)
# 25. check_required_aesthetics(self$geom$required_aes, c(names(data),
#   .     names(self$aes_params)), snake_class(self$geom))
# 26. cli::cli_abort(message, call = call)
# 27. rlang::abort(message, ..., call = call, use_cli_format = TRUE,
#   .     .frame = .frame)
# 28. signal_abort(cnd, .file)
# 29. signalCondition(cnd)
# 30. (function (cnd)
#   . {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .     }
#   .     out <- handlers[[1L]](cnd)
#   .     if (!inherits(out, "rlang_zap"))
#   .         throw(out)
#   . })(structure(list(message = "`geom_point()` requires the following missing aesthetics: \033y\033",
#   .     trace = structure(list(call = list(IRkernel::main(), kernel$run(),
#   .         handle_shell(), executor$execute(msg), tryCatch(evaluate(request$content$code,
#   .             envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .             interrupt = function(cond) {
#   .                 log_debug("Interrupt during execution")
#   .                 interrupted <<- TRUE
#   .             }, error = .self$handle_error), tryCatchList(expr,
#   .             classes, parentenv, handlers), tryCatchOne(tryCatchList(expr,
#   .             names[-nh], parentenv, handlers[-nh]), names[nh],
#   .             parentenv, handlers[[nh]]), doTryCatch(return(expr),
#   .             name, parentenv, handler), tryCatchList(expr, names[-nh],
#   .             parentenv, handlers[-nh]), tryCatchOne(expr, names,
#   .             parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .             name, parentenv, handler), evaluate(request$content$code,
#   .             envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .         evaluate_call(expr, parsed$src[[i]], envir = envir, enclos = enclos,
#   .             debug = debug, last = i == length(out), use_try = stop_on_error !=
#   .                 2L, keep_warning = keep_warning, keep_message = keep_message,
#   .             output_handler = output_handler, include_timing = include_timing),
#   .         handle(pv <- withCallingHandlers(withVisible(value_fun(ev$value,
#   .             ev$visible)), warning = wHandler, error = eHandler,
#   .             message = mHandler)), try(f, silent = TRUE), tryCatch(expr,
#   .             error = function(e) {
#   .                 call <- conditionCall(e)
#   .                 if (!is.null(call)) {
#   .                   if (identical(call[[1L]], quote(doTryCatch)))
#   .                     call <- sys.call(-4L)
#   .                   dcall <- deparse(call, nlines = 1L)
#   .                   prefix <- paste("Error in", dcall, ": ")
#   .                   LONG <- 75L
#   .                   sm <- strsplit(conditionMessage(e), "\n")[[1L]]
#   .                   w <- 14L + nchar(dcall, type = "w") + nchar(sm[1L],
#   .                     type = "w")
#   .                   if (is.na(w))
#   .                     w <- 14L + nchar(dcall, type = "b") + nchar(sm[1L],
#   .                       type = "b")
#   .                   if (w > LONG)
#   .                     prefix <- paste0(prefix, "\n  ")
#   .                 }
#   .                 else prefix <- "Error : "
#   .                 msg <- paste0(prefix, conditionMessage(e), "\n")
#   .                 .Internal(seterrmessage(msg[1L]))
#   .                 if (!silent && isTRUE(getOption("show.error.messages"))) {
#   .                   cat(msg, file = outFile)
#   .                   .Internal(printDeferredWarnings())
#   .                 }
#   .                 invisible(structure(msg, class = "try-error",
#   .                   condition = e))
#   .             }), tryCatchList(expr, classes, parentenv, handlers),
#   .         tryCatchOne(expr, names, parentenv, handlers[[1L]]),
#   .         doTryCatch(return(expr), name, parentenv, handler), withCallingHandlers(withVisible(value_fun(ev$value,
#   .             ev$visible)), warning = wHandler, error = eHandler,
#   .             message = mHandler), withVisible(value_fun(ev$value,
#   .             ev$visible)), value_fun(ev$value, ev$visible), prepare_mimebundle_kernel(obj,
#   .             .self$handle_display_error), prepare_mimebundle(obj,
#   .             "text/plain", error_handler = handle_display_error),
#   .         filter_map(mimetypes, function(mime) {
#   .             tryCatch(withCallingHandlers({
#   .                 if (!mime %in% names(repr::mime2repr))
#   .                   stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#   .                 rpr <- repr::mime2repr[[mime]](obj)
#   .                 if (is.null(rpr))
#   .                   return(NULL)
#   .                 prepare_content(is.raw(rpr), rpr)
#   .             }, error = error_handler), error = outer_handler)
#   .         }), Filter(Negate(is.null), sapply(x, f, simplify = simplify)),
#   .         unlist(lapply(x, f)), lapply(x, f), sapply(x, f, simplify = simplify),
#   .         lapply(X = X, FUN = FUN, ...), FUN(X[[i]], ...), tryCatch(withCallingHandlers({
#   .             if (!mime %in% names(repr::mime2repr))
#   .                 stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#   .             rpr <- repr::mime2repr[[mime]](obj)
#   .             if (is.null(rpr))
#   .                 return(NULL)
#   .             prepare_content(is.raw(rpr), rpr)
#   .         }, error = error_handler), error = outer_handler), tryCatchList(expr,
#   .             classes, parentenv, handlers), tryCatchOne(expr,
#   .             names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .             name, parentenv, handler), withCallingHandlers({
#   .             if (!mime %in% names(repr::mime2repr))
#   .                 stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#   .             rpr <- repr::mime2repr[[mime]](obj)
#   .             if (is.null(rpr))
#   .                 return(NULL)
#   .             prepare_content(is.raw(rpr), rpr)
#   .         }, error = error_handler), repr::mime2repr[[mime]](obj),
#   .         repr_text.default(obj), paste(capture.output(print(obj)),
#   .             collapse = "\n"), capture.output(print(obj)), withVisible(...elt(i)),
#   .         print(obj), print.ggplot(obj), ggplot_build(x), ggplot_build.ggplot(x),
#   .         by_layer(function(l, d) l$compute_geom_1(d), layers,
#   .             data, "setting up geom"), try_fetch(for (i in seq_along(data)) {
#   .             out[[i]] <- f(l = layers[[i]], d = data[[i]])
#   .         }, error = function(cnd) {
#   .             cli::cli_abort(c("Problem while {step}.", i = "Error occurred in the {ordinal(i)} layer."),
#   .                 call = layers[[i]]$constructor, parent = cnd)
#   .         }), tryCatch(withCallingHandlers(expr, error = function(cnd) {
#   .             {
#   .                 .__handler_frame__. <- TRUE
#   .                 .__setup_frame__. <- frame
#   .             }
#   .             out <- handlers[[1L]](cnd)
#   .             if (!inherits(out, "rlang_zap"))
#   .                 throw(out)
#   .         }), stackOverflowError = handlers[[1L]]), tryCatchList(expr,
#   .             classes, parentenv, handlers), tryCatchOne(expr,
#   .             names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .             name, parentenv, handler), withCallingHandlers(expr,
#   .             error = function(cnd) {
#   .                 {
#   .                   .__handler_frame__. <- TRUE
#   .                   .__setup_frame__. <- frame
#   .                 }
#   .                 out <- handlers[[1L]](cnd)
#   .                 if (!inherits(out, "rlang_zap"))
#   .                   throw(out)
#   .             }), f(l = layers[[i]], d = data[[i]]), l$compute_geom_1(d),
#   .         compute_geom_1(..., self = self), check_required_aesthetics(self$geom$required_aes,
#   .             c(names(data), names(self$aes_params)), snake_class(self$geom)),
#   .         cli::cli_abort(message, call = call), rlang::abort(message,
#   .             ..., call = call, use_cli_format = TRUE, .frame = .frame)),
#   .         parent = c(0L, 1L, 2L, 3L, 4L, 5L, 6L, 7L, 6L, 9L, 10L,
#   .         4L, 12L, 13L, 14L, 15L, 16L, 17L, 18L, 13L, 13L, 13L,
#   .         22L, 23L, 24L, 25L, 26L, 26L, 25L, 29L, 30L, 31L, 32L,
#   .         33L, 34L, 31L, 31L, 31L, 38L, 38L, 40L, 38L, 38L, 43L,
#   .         43L, 45L, 46L, 47L, 48L, 49L, 50L, 47L, 46L, 53L, 54L,
#   .         55L, 56L, 57L), visible = c(TRUE, TRUE, TRUE, TRUE, TRUE,
#   .         TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   .         TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   .         TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   .         TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   .         TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   .         TRUE, TRUE, TRUE, TRUE, TRUE, FALSE, FALSE, FALSE), namespace = c("IRkernel",
#   .         NA, "IRkernel", NA, "base", "base", "base", "base", "base",
#   .         "base", "base", "evaluate", "evaluate", "evaluate", "base",
#   .         "base", "base", "base", "base", "base", "base", "IRkernel",
#   .         "IRkernel", "IRdisplay", "IRdisplay", "base", "base",
#   .         "base", "base", "base", "IRdisplay", "base", "base",
#   .         "base", "base", "base", NA, "repr", "base", "utils",
#   .         "base", "base", "ggplot2", "ggplot2", "ggplot2", "ggplot2",
#   .         "rlang", "base", "base", "base", "base", "base", "ggplot2",
#   .         NA, "ggplot2", "ggplot2", "cli", "rlang"), scope = c("::",
#   .         NA, "local", NA, "::", "local", "local", "local", "local",
#   .         "local", "local", "::", ":::", "local", "::", "::", "local",
#   .         "local", "local", "::", "::", "local", ":::", "::", ":::",
#   .         "::", "::", "::", "::", "::", "local", "::", "local",
#   .         "local", "local", "::", NA, ":::", "::", "::", "::",
#   .         "::", ":::", "::", ":::", ":::", "::", "::", "local",
#   .         "local", "local", "::", "local", NA, "local", ":::",
#   .         "::", "::"), error_frame = c(FALSE, FALSE, FALSE, FALSE,
#   .         FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .         FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .         FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .         FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .         FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .         FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .         FALSE, FALSE, TRUE, FALSE, FALSE, FALSE)), row.names = c(NA,
#   .     -58L), version = 2L, class = c("rlang_trace", "rlib_trace",
#   .     "tbl", "data.frame")), parent = NULL, call = compute_geom_1(...,
#   .         self = self), use_cli_format = TRUE), class = c("rlang_error",
#   . "error", "condition")))
# 31. handlers[[1L]](cnd)
# 32. cli::cli_abort(c("Problem while {step}.", i = "Error occurred in the {ordinal(i)} layer."),
#   .     call = layers[[i]]$constructor, parent = cnd)
# 33. rlang::abort(message, ..., call = call, use_cli_format = TRUE,
#   .     .frame = .frame)
# 34. signal_abort(cnd, .file)

# %%
for (column in colnames(data[5:22])) {
    plt <- ggplot() + geom_point(aes(data[,column], data$life_expectancy)) + ggtitle(column)
    show(plt)
}
# Out:
# Warning message:
# "Removed 10 rows containing missing values (`geom_point()`)."
# Warning message:
# "Removed 10 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 203 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 10 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 563 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 10 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 42 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 10 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 29 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 236 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 29 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 10 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 453 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 654 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 42 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 42 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 170 rows containing missing values (`geom_point()`)."
# plot without title
# Warning message:
# "Removed 170 rows containing missing values (`geom_point()`)."
# plot without title
# plot without title
